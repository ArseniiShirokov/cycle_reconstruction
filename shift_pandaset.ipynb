# %% [markdown]
# ### Params

# %%
# !ls -l outputs/full_split/splatad/
# Out:
# total 40
# drwxr-xr-x 3 jovyan jovyan 4096 Sep 28 17:09 2025-09-28_170104
# drwxr-xr-x 3 jovyan jovyan 4096 Oct  2 16:08 2025-10-02_160038
# drwxr-xr-x 3 jovyan jovyan 4096 Oct  2 16:14 2025-10-02_160936
# drwxr-xr-x 3 jovyan jovyan 4096 Oct  2 16:15 2025-10-02_161154
# drwxr-xr-x 3 jovyan jovyan 4096 Oct  2 16:20 2025-10-02_161658
# drwxr-xr-x 3 jovyan jovyan 4096 Oct  2 16:23 2025-10-02_161940
# drwxr-xr-x 3 jovyan jovyan 4096 Oct  2 16:27 2025-10-02_162120
# drwxr-xr-x 3 jovyan jovyan 4096 Oct  2 16:28 2025-10-02_162326
# drwxr-xr-x 3 jovyan jovyan 4096 Oct  2 16:41 2025-10-02_163623
# drwxr-xr-x 3 jovyan jovyan 4096 Oct  2 17:13 2025-10-02_170733

# %%
folder2seq = {
    "2025-09-28_170104": "001",
    "2025-10-02_160038": "011",
    "2025-10-02_160936": "016",
    "2025-10-02_161154": "028",
}

# %%
folder = "2025-10-02_160038"
cfg = f"outputs/full_split/splatad/{folder}/config.yml"
seq = folder2seq[folder]
shift = [-3.0, 0.0, 0.0]

str_shift = f"{shift[0]} {shift[1]} {shift[2]}"

# %% [markdown]
# ### Rendering

# %%
# !python nerfstudio/scripts/render.py dataset --load-config {cfg} --output_path shifted/{seq} --shift {str_shift} --render_point_clouds False
# Out:
# 2025-10-03 02:15:57.047793: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-10-03 02:15:57.207136: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-10-03 02:15:58.524144: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/lib:/home/jovyan/users/npatakin/libs/cuda-11.8/lib64
# 2025-10-03 02:15:58.524257: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/lib:/home/jovyan/users/npatakin/libs/cuda-11.8/lib64
# 2025-10-03 02:15:58.524268: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Waymo dataparser has missing dependencies, please following installation instructions in README.md
# [02:16:37] Painting lidar points                                                    ]8;id=455914;file:///home/jovyan/users/shirokov/third-party/neurad-studio/nerfstudio/data/datamanagers/full_images_lidar_datamanager.py\full_images_lidar_datamanager.py]8;;\:]8;id=222548;file:///home/jovyan/users/shirokov/third-party/neurad-studio/nerfstudio/data/datamanagers/full_images_lidar_datamanager.py#121\121]8;;\
#            Caching / undistorting train images                                            ]8;id=570388;file:///home/jovyan/users/shirokov/third-party/neurad-studio/nerfstudio/data/datamanagers/full_images_datamanager.py\full_images_datamanager.py]8;;\:]8;id=654217;file:///home/jovyan/users/shirokov/third-party/neurad-studio/nerfstudio/data/datamanagers/full_images_datamanager.py#240\240]8;;\
# /home/jovyan/users/shirokov/third-party/neurad-studio/nerfstudio/data/datamanage5m  0% -:--:--
# rs/full_images_datamanager.py:214: UserWarning: The size of image (1920, 1080)
# loaded does not match the camera parameters (1920, 820).The image will be
# cropped after distortion correction.
#   warnings.warn(
# Caching / undistorting train images ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:0300:0100:01
# [02:16:42] Caching train lidars                                                     ]8;id=576518;file:///home/jovyan/users/shirokov/third-party/neurad-studio/nerfstudio/data/datamanagers/full_images_lidar_datamanager.py\full_images_lidar_datamanager.py]8;;\:]8;id=531078;file:///home/jovyan/users/shirokov/third-party/neurad-studio/nerfstudio/data/datamanagers/full_images_lidar_datamanager.py#298\298]8;;\
# Caching train lidars ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
# Loading latest checkpoint from load_dir
# ✅ Done loading checkpoint from outputs/full_split/splatad/2025-10-02_160038/nerfstudio_models/step-000030000.ckpt
# [02:18:03] Painting lidar points                                                    ]8;id=628499;file:///home/jovyan/users/shirokov/third-party/neurad-studio/nerfstudio/data/datamanagers/full_images_lidar_datamanager.py\full_images_lidar_datamanager.py]8;;\:]8;id=922091;file:///home/jovyan/users/shirokov/third-party/neurad-studio/nerfstudio/data/datamanagers/full_images_lidar_datamanager.py#121\121]8;;\
#            Caching / undistorting train images                                            ]8;id=934312;file:///home/jovyan/users/shirokov/third-party/neurad-studio/nerfstudio/data/datamanagers/full_images_datamanager.py\full_images_datamanager.py]8;;\:]8;id=267520;file:///home/jovyan/users/shirokov/third-party/neurad-studio/nerfstudio/data/datamanagers/full_images_datamanager.py#240\240]8;;\
# /home/jovyan/users/shirokov/third-party/neurad-studio/nerfstudio/data/datamanage5m  0% -:--:--
# rs/full_images_datamanager.py:214: UserWarning: The size of image (1920, 1080)
# loaded does not match the camera parameters (1920, 820).The image will be
# cropped after distortion correction.
#   warnings.warn(
# Caching / undistorting train images ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:0300:0100:01
# [02:18:07] Caching train lidars                                                     ]8;id=915355;file:///home/jovyan/users/shirokov/third-party/neurad-studio/nerfstudio/data/datamanagers/full_images_lidar_datamanager.py\full_images_lidar_datamanager.py]8;;\:]8;id=58434;file:///home/jovyan/users/shirokov/third-party/neurad-studio/nerfstudio/data/datamanagers/full_images_lidar_datamanager.py#298\298]8;;\
# Caching train lidars ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
# [02:18:12] Caching eval lidars                                                      ]8;id=707576;file:///home/jovyan/users/shirokov/third-party/neurad-studio/nerfstudio/data/datamanagers/full_images_lidar_datamanager.py\full_images_lidar_datamanager.py]8;;\:]8;id=324788;file:///home/jovyan/users/shirokov/third-party/neurad-studio/nerfstudio/data/datamanagers/full_images_lidar_datamanager.py#298\298]8;;\
# Caching eval lidars ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
# 🎥 Rendering split test 🎥 ━━━━━━━━━━━ 480/480(100.0%) 10.34 fps 0:00:00 0:00:4900:4900:45
# ╭─ 🎉 Render on split {} Complete 🎉 ─╮
# │                ╷                    │
# │   Outputs test │ shifted/011/test   │
# │                ╵                    │
# ╰─────────────────────────────────────╯

# %% [markdown]
# ### Video check

# %%
selected_cameras = ["left_camera", "front_camera"]
base_folder = f"shifted/{seq}/test"
fps = 10

# %%
import imageio
from PIL import Image, ImageDraw, ImageFont
from pathlib import Path
import glob
import os
import numpy as np

def create_video_with_imageio(base_folder, camera_name, output_path, fps=10, reverse=False):
    # Get image paths
    if camera_name == "lidar":
        rgb_folder = Path(base_folder)
        gt_rgb_folder = Path(base_folder)
        rgb_camera_path = os.path.join(rgb_folder, "lidar_vis" )
        gt_rgb_camera_path = os.path.join(gt_rgb_folder, "lidar_vis_gt")
        rgb_images = sorted(glob.glob(os.path.join(rgb_camera_path, "*.png")))
        gt_rgb_images = sorted(glob.glob(os.path.join(gt_rgb_camera_path, "*.png")))
    else:
        rgb_folder = Path(base_folder) / "rgb" 
        gt_rgb_folder = Path(base_folder) / "gt-rgb"
        rgb_camera_path = os.path.join(rgb_folder, camera_name)
        gt_rgb_camera_path = os.path.join(gt_rgb_folder, camera_name)
        rgb_images = sorted(glob.glob(os.path.join(rgb_camera_path, "*.jpg")))
        gt_rgb_images = sorted(glob.glob(os.path.join(gt_rgb_camera_path, "*.jpg")))
        
    frames = []
    for i, (rgb_path, gt_rgb_path) in enumerate(zip(rgb_images, gt_rgb_images)):
        # Read images using PIL
        rgb_img = Image.open(rgb_path)
        gt_rgb_img = Image.open(gt_rgb_path)
        
        # Get dimensions
        w, h = rgb_img.size

        w = int(w * 0.4)
        h = int(h * 0.4)
        
        # Resize GT image to match RGB if needed
        gt_rgb_img = gt_rgb_img.resize((w, h))
        rgb_img = rgb_img.resize((w, h))
        
        # Create side-by-side image
        combined_img = Image.new('RGB', (w * 2, h))
        combined_img.paste(rgb_img, (0, 0))
        combined_img.paste(gt_rgb_img, (w, 0))
        
        # Add text labels using PIL
        draw = ImageDraw.Draw(combined_img)
        try:
            font = ImageFont.truetype("/usr/share/fonts/truetype/dejavu/DejaVuSans-Bold.ttf", 20)
        except:
            font = ImageFont.load_default()
        
        # Add labels
        if camera_name != "lidar":
            if reverse:
                draw.text((10, 10), f'Reverse shift', fill=(255, 255, 255), font=font)
                draw.text((w + 10, 10), f'Ground Truth with shift {shift}', fill=(255, 255, 255), font=font)
            else:
                draw.text((10, 10), f'Shift {shift}', fill=(255, 255, 255), font=font)
                draw.text((w + 10, 10), 'Ground Truth', fill=(255, 255, 255), font=font)

        frame_array = np.array(combined_img)
        frames.append(frame_array)
    imageio.mimsave(output_path, frames, fps=fps)

(Path(base_folder) / "videos").mkdir(parents=True, exist_ok=True)


# for selected_camera in selected_cameras:
#     output_video_path = Path(base_folder) / "videos" / f"{selected_camera}.mp4"
#     create_video_with_imageio(base_folder, selected_camera, output_video_path, fps)

# %% [markdown]
# ### Final dataset

# %%
# !python nerfstudio/scripts/render.py dataset --load-config {cfg} --output_path shifted/{seq} --shift {str_shift} --render_point_clouds True
# Out:
# 2025-10-03 02:29:13.796128: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-10-03 02:29:13.953417: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-10-03 02:29:15.310966: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/lib:/home/jovyan/users/npatakin/libs/cuda-11.8/lib64
# 2025-10-03 02:29:15.311086: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/lib:/home/jovyan/users/npatakin/libs/cuda-11.8/lib64
# 2025-10-03 02:29:15.311097: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Waymo dataparser has missing dependencies, please following installation instructions in README.md
# [02:29:55] Painting lidar points                                                    ]8;id=933836;file:///home/jovyan/users/shirokov/third-party/neurad-studio/nerfstudio/data/datamanagers/full_images_lidar_datamanager.py\full_images_lidar_datamanager.py]8;;\:]8;id=183290;file:///home/jovyan/users/shirokov/third-party/neurad-studio/nerfstudio/data/datamanagers/full_images_lidar_datamanager.py#121\121]8;;\
#            Caching / undistorting train images                                            ]8;id=860393;file:///home/jovyan/users/shirokov/third-party/neurad-studio/nerfstudio/data/datamanagers/full_images_datamanager.py\full_images_datamanager.py]8;;\:]8;id=180263;file:///home/jovyan/users/shirokov/third-party/neurad-studio/nerfstudio/data/datamanagers/full_images_datamanager.py#240\240]8;;\
# /home/jovyan/users/shirokov/third-party/neurad-studio/nerfstudio/data/datamanage5m  0% -:--:--
# rs/full_images_datamanager.py:214: UserWarning: The size of image (1920, 1080)
# loaded does not match the camera parameters (1920, 820).The image will be
# cropped after distortion correction.
#   warnings.warn(
# Caching / undistorting train images ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:04m 0:00:01
# [02:30:00] Caching train lidars                                                     ]8;id=150119;file:///home/jovyan/users/shirokov/third-party/neurad-studio/nerfstudio/data/datamanagers/full_images_lidar_datamanager.py\full_images_lidar_datamanager.py]8;;\:]8;id=926591;file:///home/jovyan/users/shirokov/third-party/neurad-studio/nerfstudio/data/datamanagers/full_images_lidar_datamanager.py#298\298]8;;\
# Caching train lidars ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
# Loading latest checkpoint from load_dir
# ✅ Done loading checkpoint from outputs/full_split/splatad/2025-10-02_160038/nerfstudio_models/step-000030000.ckpt
# [02:31:21] Painting lidar points                                                    ]8;id=142307;file:///home/jovyan/users/shirokov/third-party/neurad-studio/nerfstudio/data/datamanagers/full_images_lidar_datamanager.py\full_images_lidar_datamanager.py]8;;\:]8;id=472713;file:///home/jovyan/users/shirokov/third-party/neurad-studio/nerfstudio/data/datamanagers/full_images_lidar_datamanager.py#121\121]8;;\
#            Caching / undistorting train images                                            ]8;id=62017;file:///home/jovyan/users/shirokov/third-party/neurad-studio/nerfstudio/data/datamanagers/full_images_datamanager.py\full_images_datamanager.py]8;;\:]8;id=497381;file:///home/jovyan/users/shirokov/third-party/neurad-studio/nerfstudio/data/datamanagers/full_images_datamanager.py#240\240]8;;\
# /home/jovyan/users/shirokov/third-party/neurad-studio/nerfstudio/data/datamanage5m  0% -:--:--
# rs/full_images_datamanager.py:214: UserWarning: The size of image (1920, 1080)
# loaded does not match the camera parameters (1920, 820).The image will be
# cropped after distortion correction.
#   warnings.warn(
# Caching / undistorting train images ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:0300:0100:01
# [02:31:25] Caching train lidars                                                     ]8;id=664380;file:///home/jovyan/users/shirokov/third-party/neurad-studio/nerfstudio/data/datamanagers/full_images_lidar_datamanager.py\full_images_lidar_datamanager.py]8;;\:]8;id=512471;file:///home/jovyan/users/shirokov/third-party/neurad-studio/nerfstudio/data/datamanagers/full_images_lidar_datamanager.py#298\298]8;;\
# Caching train lidars ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
# [02:31:29] Caching eval lidars                                                      ]8;id=190084;file:///home/jovyan/users/shirokov/third-party/neurad-studio/nerfstudio/data/datamanagers/full_images_lidar_datamanager.py\full_images_lidar_datamanager.py]8;;\:]8;id=889326;file:///home/jovyan/users/shirokov/third-party/neurad-studio/nerfstudio/data/datamanagers/full_images_lidar_datamanager.py#298\298]8;;\
# Caching eval lidars ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
# 🎥 Rendering split test 🎥 ━━━━━━━━━━━ 480/480(100.0%) 10.21 fps 0:00:00 0:00:4900:4900:45
# 🎥 Rendering lidars for split test 🎥 ━━━━━━━ 2/80(2.5%) 1.43    0:00:55 0:00:01
# 🎥 Rendering lidars for split test 🎥 ━━━━━━━ 2/80(2.5%) 1.43    0:00:55 0:00:01
# 🎥 Rendering lidars for split test 🎥 ━━━━━━━ 2/80(2.5%) 1.43    0:00:55 0:00:01
# 🎥 Rendering lidars for split test 🎥 ━━━━━━━ 2/80(2.5%) 1.43    0:00:55 0:00:01
# 🎥 Rendering lidars for split test 🎥 ━━━━━━━ 2/80(2.5%) 1.43    0:00:55 0:00:01
# 🎥 Rendering lidars for split test 🎥 ━━━━━━━ 2/80(2.5%) 1.43    0:00:55 0:00:02
# 🎥 Rendering lidars for split test 🎥 ━━━━━━━ 2/80(2.5%) 1.43    0:00:55 0:00:02
# 🎥 Rendering lidars for split test 🎥 ━━━━━━━ 2/80(2.5%) 1.43    0:00:55 0:00:02
# 🎥 Rendering lidars for split test 🎥 ━━━━━━━ 3/80(3.8%) 1.33    0:00:58 0:00:02
# 🎥 Rendering lidars for split test 🎥 ━━━━━━━ 3/80(3.8%) 1.33    0:00:58 0:00:02
# 🎥 Rendering lidars for split test 🎥 ━━━━━━━ 3/80(3.8%) 1.33    0:00:58 0:00:02
# 🎥 Rendering lidars for split test 🎥 ━━━━━━━ 3/80(3.8%) 1.33    0:00:58 0:00:02
# 🎥 Rendering lidars for split test 🎥 ━━━━━━━ 3/80(3.8%) 1.33    0:00:58 0:00:02
# 🎥 Rendering lidars for split test 🎥 ━━━━━━━ 3/80(3.8%) 1.33    0:00:58 0:00:02
# 🎥 Rendering lidars for split test 🎥 ━━━━━━━ 3/80(3.8%) 1.33    0:00:58 0:00:02
# 🎥 Rendering lidars for split test 🎥 ━━━━━━━ 4/80(5.0%) 1.36    0:00:56 0:00:03
# 🎥 Rendering lidars for split test 🎥 ━━━━━━━ 4/80(5.0%) 1.36    0:00:56 0:00:03
# 🎥 Rendering lidars for split test 🎥 ━━━━━━━ 4/80(5.0%) 1.36    0:00:56 0:00:03
# 🎥 Rendering lidars for split test 🎥 ━━━━━━━ 4/80(5.0%) 1.36    0:00:56 0:00:03
# 🎥 Rendering lidars for split test 🎥 ━━━━━━━ 4/80(5.0%) 1.36    0:00:56 0:00:03
# 🎥 Rendering lidars for split test 🎥 ━━━━━━━ 4/80(5.0%) 1.36    0:00:56 0:00:03
# 🎥 Rendering lidars for split test 🎥 ━━━━━━━ 4/80(5.0%) 1.36    0:00:56 0:00:03
# 🎥 Rendering lidars for split test 🎥 ━━━━━━━ 5/80(6.2%) 1.38    0:00:55 0:00:03
# 🎥 Rendering lidars for split test 🎥 ━━━━━━━ 5/80(6.2%) 1.38    0:00:55 0:00:03
# 🎥 Rendering lidars for split test 🎥 ━━━━━━━ 5/80(6.2%) 1.38    0:00:55 0:00:03
# 🎥 Rendering lidars for split test 🎥 ━━━━━━━ 5/80(6.2%) 1.38    0:00:55 0:00:04
# 🎥 Rendering lidars for split test 🎥 ━━━━━━━ 5/80(6.2%) 1.38    0:00:55 0:00:04
# 🎥 Rendering lidars for split test 🎥 ━━━━━━━ 5/80(6.2%) 1.38    0:00:55 0:00:04
# 🎥 Rendering lidars for split test 🎥 ━━━━━━━ 5/80(6.2%) 1.38    0:00:55 0:00:04
# 🎥 Rendering lidars for split test 🎥 ╸━━━━━━ 6/80(7.5%) 1.39    0:00:54 0:00:04
# 🎥 Rendering lidars for split test 🎥 ╸━━━━━━ 6/80(7.5%) 1.39    0:00:54 0:00:04
# 🎥 Rendering lidars for split test 🎥 ╸━━━━━━ 6/80(7.5%) 1.39    0:00:54 0:00:04
# 🎥 Rendering lidars for split test 🎥 ╸━━━━━━ 6/80(7.5%) 1.39    0:00:54 0:00:04
# 🎥 Rendering lidars for split test 🎥 ╸━━━━━━ 6/80(7.5%) 1.39    0:00:54 0:00:04
# 🎥 Rendering lidars for split test 🎥 ╸━━━━━━ 6/80(7.5%) 1.39    0:00:54 0:00:04
# 🎥 Rendering lidars for split test 🎥 ╸━━━━━━ 6/80(7.5%) 1.39    0:00:54 0:00:05
# 🎥 Rendering lidars for split test 🎥 ╸━━━━━━ 6/80(7.5%) 1.39    0:00:54 0:00:05
# 🎥 Rendering lidars for split test 🎥 ╸━━━━━━ 7/80(8.8%) 1.36    0:00:54 0:00:05
# 🎥 Rendering lidars for split test 🎥 ╸━━━━━━ 7/80(8.8%) 1.36    0:00:54 0:00:05
# 🎥 Rendering lidars for split test 🎥 ╸━━━━━━ 7/80(8.8%) 1.36    0:00:54 0:00:05
# 🎥 Rendering lidars for split test 🎥 ╸━━━━━━ 7/80(8.8%) 1.36    0:00:54 0:00:05
# 🎥 Rendering lidars for split test 🎥 ╸━━━━━━ 7/80(8.8%) 1.36    0:00:54 0:00:05
# 🎥 Rendering lidars for split test 🎥 ╸━━━━━━ 7/80(8.8%) 1.36    0:00:54 0:00:05
# 🎥 Rendering lidars for split test 🎥 ╸━━━━━━ 7/80(8.8%) 1.36    0:00:54 0:00:05
# 🎥 Rendering lidars for split test 🎥 ╸━━━━━━ 8/80(10.0%) 1.37    0:00:… 0:00:05
# 🎥 Rendering lidars for split test 🎥 ╸━━━━━━ 8/80(10.0%) 1.37    0:00:… 0:00:06
# 🎥 Rendering lidars for split test 🎥 ╸━━━━━━ 8/80(10.0%) 1.37    0:00:… 0:00:06
# 🎥 Rendering lidars for split test 🎥 ╸━━━━━━ 8/80(10.0%) 1.37    0:00:… 0:00:06
# 🎥 Rendering lidars for split test 🎥 ╸━━━━━━ 8/80(10.0%) 1.37    0:00:… 0:00:06
# 🎥 Rendering lidars for split test 🎥 ╸━━━━━━ 8/80(10.0%) 1.37    0:00:… 0:00:06
# 🎥 Rendering lidars for split test 🎥 ╸━━━━━━ 9/80(11.2%) 1.38    0:00:… 0:00:06
# 🎥 Rendering lidars for split test 🎥 ╸━━━━━━ 9/80(11.2%) 1.38    0:00:… 0:00:06
# 🎥 Rendering lidars for split test 🎥 ╸━━━━━━ 9/80(11.2%) 1.38    0:00:… 0:00:06
# 🎥 Rendering lidars for split test 🎥 ╸━━━━━━ 9/80(11.2%) 1.38    0:00:… 0:00:06
# 🎥 Rendering lidars for split test 🎥 ╸━━━━━━ 9/80(11.2%) 1.38    0:00:… 0:00:07
# 🎥 Rendering lidars for split test 🎥 ╸━━━━━━ 9/80(11.2%) 1.38    0:00:… 0:00:07
# 🎥 Rendering lidars for split test 🎥 ╸━━━━━━ 9/80(11.2%) 1.38    0:00:… 0:00:07
# 🎥 Rendering lidars for split test 🎥 ╸━━━━━ 10/80(12.5%) 1.38    0:00:… 0:00:07
# 🎥 Rendering lidars for split test 🎥 ╸━━━━━ 10/80(12.5%) 1.38    0:00:… 0:00:07
# 🎥 Rendering lidars for split test 🎥 ╸━━━━━ 10/80(12.5%) 1.38    0:00:… 0:00:07
# 🎥 Rendering lidars for split test 🎥 ╸━━━━━ 10/80(12.5%) 1.38    0:00:… 0:00:07
# 🎥 Rendering lidars for split test 🎥 ╸━━━━━ 10/80(12.5%) 1.38    0:00:… 0:00:07
# 🎥 Rendering lidars for split test 🎥 ╸━━━━━ 10/80(12.5%) 1.38    0:00:… 0:00:07
# 🎥 Rendering lidars for split test 🎥 ╸━━━━━ 10/80(12.5%) 1.38    0:00:… 0:00:07
# 🎥 Rendering lidars for split test 🎥 ╸━━━━━ 11/80(13.8%) 1.39    0:00:… 0:00:08
# 🎥 Rendering lidars for split test 🎥 ╸━━━━━ 11/80(13.8%) 1.39    0:00:… 0:00:08
# 🎥 Rendering lidars for split test 🎥 ╸━━━━━ 11/80(13.8%) 1.39    0:00:… 0:00:08
# 🎥 Rendering lidars for split test 🎥 ╸━━━━━ 11/80(13.8%) 1.39    0:00:… 0:00:08
# 🎥 Rendering lidars for split test 🎥 ╸━━━━━ 11/80(13.8%) 1.39    0:00:… 0:00:08
# 🎥 Rendering lidars for split test 🎥 ╸━━━━━ 11/80(13.8%) 1.39    0:00:… 0:00:08
# 🎥 Rendering lidars for split test 🎥 ╸━━━━━ 11/80(13.8%) 1.39    0:00:… 0:00:08
# 🎥 Rendering lidars for split test 🎥 ╸━━━━━ 12/80(15.0%) 1.39    0:00:… 0:00:08
# 🎥 Rendering lidars for split test 🎥 ╸━━━━━ 12/80(15.0%) 1.39    0:00:… 0:00:08
# 🎥 Rendering lidars for split test 🎥 ╸━━━━━ 12/80(15.0%) 1.39    0:00:… 0:00:08
# 🎥 Rendering lidars for split test 🎥 ╸━━━━━ 12/80(15.0%) 1.39    0:00:… 0:00:09
# 🎥 Rendering lidars for split test 🎥 ╸━━━━━ 12/80(15.0%) 1.39    0:00:… 0:00:09
# 🎥 Rendering lidars for split test 🎥 ╸━━━━━ 12/80(15.0%) 1.39    0:00:… 0:00:09
# 🎥 Rendering lidars for split test 🎥 ╸━━━━━ 12/80(15.0%) 1.39    0:00:… 0:00:09
# 🎥 Rendering lidars for split test 🎥 ╸━━━━━ 13/80(16.2%) 1.39    0:00:… 0:00:09
# 🎥 Rendering lidars for split test 🎥 ╸━━━━━ 13/80(16.2%) 1.39    0:00:… 0:00:09
# 🎥 Rendering lidars for split test 🎥 ╸━━━━━ 13/80(16.2%) 1.39    0:00:… 0:00:09
# 🎥 Rendering lidars for split test 🎥 ╸━━━━━ 13/80(16.2%) 1.39    0:00:… 0:00:09
# 🎥 Rendering lidars for split test 🎥 ╸━━━━━ 13/80(16.2%) 1.39    0:00:… 0:00:09
# 🎥 Rendering lidars for split test 🎥 ╸━━━━━ 13/80(16.2%) 1.39    0:00:… 0:00:09
# 🎥 Rendering lidars for split test 🎥 ╸━━━━━ 13/80(16.2%) 1.39    0:00:… 0:00:10
# 🎥 Rendering lidars for split test 🎥 ━╺━━━━ 14/80(17.5%) 1.40    0:00:… 0:00:10
# 🎥 Rendering lidars for split test 🎥 ━╺━━━━ 14/80(17.5%) 1.40    0:00:… 0:00:10
# 🎥 Rendering lidars for split test 🎥 ━╺━━━━ 14/80(17.5%) 1.40    0:00:… 0:00:10
# 🎥 Rendering lidars for split test 🎥 ━╺━━━━ 14/80(17.5%) 1.40    0:00:… 0:00:10
# 🎥 Rendering lidars for split test 🎥 ━╺━━━━ 14/80(17.5%) 1.40    0:00:… 0:00:10
# 🎥 Rendering lidars for split test 🎥 ━╺━━━━ 14/80(17.5%) 1.40    0:00:… 0:00:10
# 🎥 Rendering lidars for split test 🎥 ━╺━━━━ 14/80(17.5%) 1.40    0:00:… 0:00:10
# 🎥 Rendering lidars for split test 🎥 ━╺━━━━ 15/80(18.8%) 1.40    0:00:… 0:00:10
# 🎥 Rendering lidars for split test 🎥 ━╺━━━━ 15/80(18.8%) 1.40    0:00:… 0:00:10
# 🎥 Rendering lidars for split test 🎥 ━╺━━━━ 15/80(18.8%) 1.40    0:00:… 0:00:11
# 🎥 Rendering lidars for split test 🎥 ━╺━━━━ 15/80(18.8%) 1.40    0:00:… 0:00:11
# 🎥 Rendering lidars for split test 🎥 ━╺━━━━ 15/80(18.8%) 1.40    0:00:… 0:00:11
# 🎥 Rendering lidars for split test 🎥 ━╺━━━━ 15/80(18.8%) 1.40    0:00:… 0:00:11
# 🎥 Rendering lidars for split test 🎥 ━╺━━━━ 15/80(18.8%) 1.40    0:00:… 0:00:11
# 🎥 Rendering lidars for split test 🎥 ━╺━━━━ 16/80(20.0%) 1.40    0:00:… 0:00:11
# 🎥 Rendering lidars for split test 🎥 ━╺━━━━ 16/80(20.0%) 1.40    0:00:… 0:00:11
# 🎥 Rendering lidars for split test 🎥 ━╺━━━━ 16/80(20.0%) 1.40    0:00:… 0:00:11
# 🎥 Rendering lidars for split test 🎥 ━╺━━━━ 16/80(20.0%) 1.40    0:00:… 0:00:11
# 🎥 Rendering lidars for split test 🎥 ━╺━━━━ 16/80(20.0%) 1.40    0:00:… 0:00:11
# 🎥 Rendering lidars for split test 🎥 ━╺━━━━ 16/80(20.0%) 1.40    0:00:… 0:00:12
# 🎥 Rendering lidars for split test 🎥 ━╺━━━━ 16/80(20.0%) 1.40    0:00:… 0:00:12
# 🎥 Rendering lidars for split test 🎥 ━╺━━━━ 17/80(21.2%) 1.40    0:00:… 0:00:12
# 🎥 Rendering lidars for split test 🎥 ━╺━━━━ 17/80(21.2%) 1.40    0:00:… 0:00:12
# 🎥 Rendering lidars for split test 🎥 ━╺━━━━ 17/80(21.2%) 1.40    0:00:… 0:00:12
# 🎥 Rendering lidars for split test 🎥 ━╺━━━━ 17/80(21.2%) 1.40    0:00:… 0:00:12
# 🎥 Rendering lidars for split test 🎥 ━╺━━━━ 17/80(21.2%) 1.40    0:00:… 0:00:12
# 🎥 Rendering lidars for split test 🎥 ━╺━━━━ 17/80(21.2%) 1.40    0:00:… 0:00:12
# 🎥 Rendering lidars for split test 🎥 ━╺━━━━ 18/80(22.5%) 1.40    0:00:… 0:00:12
# 🎥 Rendering lidars for split test 🎥 ━╺━━━━ 18/80(22.5%) 1.40    0:00:… 0:00:13
# 🎥 Rendering lidars for split test 🎥 ━╺━━━━ 18/80(22.5%) 1.40    0:00:… 0:00:13
# 🎥 Rendering lidars for split test 🎥 ━╺━━━━ 18/80(22.5%) 1.40    0:00:… 0:00:13
# 🎥 Rendering lidars for split test 🎥 ━╺━━━━ 18/80(22.5%) 1.40    0:00:… 0:00:13
# 🎥 Rendering lidars for split test 🎥 ━╺━━━━ 18/80(22.5%) 1.40    0:00:… 0:00:13
# 🎥 Rendering lidars for split test 🎥 ━╺━━━━ 18/80(22.5%) 1.40    0:00:… 0:00:13
# 🎥 Rendering lidars for split test 🎥 ━╺━━━━ 19/80(23.8%) 1.41    0:00:… 0:00:13
# 🎥 Rendering lidars for split test 🎥 ━╺━━━━ 19/80(23.8%) 1.41    0:00:… 0:00:13
# 🎥 Rendering lidars for split test 🎥 ━╺━━━━ 19/80(23.8%) 1.41    0:00:… 0:00:13
# 🎥 Rendering lidars for split test 🎥 ━╺━━━━ 19/80(23.8%) 1.41    0:00:… 0:00:13
# 🎥 Rendering lidars for split test 🎥 ━╺━━━━ 19/80(23.8%) 1.41    0:00:… 0:00:14
# 🎥 Rendering lidars for split test 🎥 ━╺━━━━ 19/80(23.8%) 1.41    0:00:… 0:00:14
# 🎥 Rendering lidars for split test 🎥 ━╺━━━━ 19/80(23.8%) 1.41    0:00:… 0:00:14
# 🎥 Rendering lidars for split test 🎥 ━╸━━━━ 20/80(25.0%) 1.41    0:00:… 0:00:14
# 🎥 Rendering lidars for split test 🎥 ━╸━━━━ 20/80(25.0%) 1.41    0:00:… 0:00:14
# 🎥 Rendering lidars for split test 🎥 ━╸━━━━ 20/80(25.0%) 1.41    0:00:… 0:00:14
# 🎥 Rendering lidars for split test 🎥 ━╸━━━━ 20/80(25.0%) 1.41    0:00:… 0:00:14
# 🎥 Rendering lidars for split test 🎥 ━╸━━━━ 20/80(25.0%) 1.41    0:00:… 0:00:14
# 🎥 Rendering lidars for split test 🎥 ━╸━━━━ 20/80(25.0%) 1.41    0:00:… 0:00:14
# 🎥 Rendering lidars for split test 🎥 ━╸━━━━ 20/80(25.0%) 1.41    0:00:… 0:00:14
# 🎥 Rendering lidars for split test 🎥 ━╸━━━━ 21/80(26.2%) 1.41    0:00:… 0:00:15
# 🎥 Rendering lidars for split test 🎥 ━╸━━━━ 21/80(26.2%) 1.41    0:00:… 0:00:15
# 🎥 Rendering lidars for split test 🎥 ━╸━━━━ 21/80(26.2%) 1.41    0:00:… 0:00:15
# 🎥 Rendering lidars for split test 🎥 ━╸━━━━ 21/80(26.2%) 1.41    0:00:… 0:00:15
# 🎥 Rendering lidars for split test 🎥 ━╸━━━━ 21/80(26.2%) 1.41    0:00:… 0:00:15
# 🎥 Rendering lidars for split test 🎥 ━╸━━━━ 21/80(26.2%) 1.41    0:00:… 0:00:15
# 🎥 Rendering lidars for split test 🎥 ━╸━━━━ 21/80(26.2%) 1.41    0:00:… 0:00:15
# 🎥 Rendering lidars for split test 🎥 ━╸━━━━ 22/80(27.5%) 1.41    0:00:… 0:00:15
# 🎥 Rendering lidars for split test 🎥 ━╸━━━━ 22/80(27.5%) 1.41    0:00:… 0:00:15
# 🎥 Rendering lidars for split test 🎥 ━╸━━━━ 22/80(27.5%) 1.41    0:00:… 0:00:15
# 🎥 Rendering lidars for split test 🎥 ━╸━━━━ 22/80(27.5%) 1.41    0:00:… 0:00:16
# 🎥 Rendering lidars for split test 🎥 ━╸━━━━ 22/80(27.5%) 1.41    0:00:… 0:00:16
# 🎥 Rendering lidars for split test 🎥 ━╸━━━━ 22/80(27.5%) 1.41    0:00:… 0:00:16
# 🎥 Rendering lidars for split test 🎥 ━╸━━━━ 22/80(27.5%) 1.41    0:00:… 0:00:16
# 🎥 Rendering lidars for split test 🎥 ━╸━━━━ 23/80(28.7%) 1.41    0:00:… 0:00:16
# 🎥 Rendering lidars for split test 🎥 ━╸━━━━ 23/80(28.7%) 1.41    0:00:… 0:00:16
# 🎥 Rendering lidars for split test 🎥 ━╸━━━━ 23/80(28.7%) 1.41    0:00:… 0:00:16
# 🎥 Rendering lidars for split test 🎥 ━╸━━━━ 23/80(28.7%) 1.41    0:00:… 0:00:16
# 🎥 Rendering lidars for split test 🎥 ━╸━━━━ 23/80(28.7%) 1.41    0:00:… 0:00:16
# 🎥 Rendering lidars for split test 🎥 ━╸━━━━ 23/80(28.7%) 1.41    0:00:… 0:00:16
# 🎥 Rendering lidars for split test 🎥 ━╸━━━━ 23/80(28.7%) 1.41    0:00:… 0:00:17
# 🎥 Rendering lidars for split test 🎥 ━╸━━━━ 24/80(30.0%) 1.41    0:00:… 0:00:17
# 🎥 Rendering lidars for split test 🎥 ━╸━━━━ 24/80(30.0%) 1.41    0:00:… 0:00:17
# 🎥 Rendering lidars for split test 🎥 ━╸━━━━ 24/80(30.0%) 1.41    0:00:… 0:00:17
# 🎥 Rendering lidars for split test 🎥 ━╸━━━━ 24/80(30.0%) 1.41    0:00:… 0:00:17
# 🎥 Rendering lidars for split test 🎥 ━╸━━━━ 24/80(30.0%) 1.41    0:00:… 0:00:17
# 🎥 Rendering lidars for split test 🎥 ━╸━━━━ 24/80(30.0%) 1.41    0:00:… 0:00:17
# 🎥 Rendering lidars for split test 🎥 ━╸━━━━ 24/80(30.0%) 1.41    0:00:… 0:00:17
# 🎥 Rendering lidars for split test 🎥 ━╸━━━━ 25/80(31.2%) 1.41    0:00:… 0:00:17
# 🎥 Rendering lidars for split test 🎥 ━╸━━━━ 25/80(31.2%) 1.41    0:00:… 0:00:18
# 🎥 Rendering lidars for split test 🎥 ━╸━━━━ 25/80(31.2%) 1.41    0:00:… 0:00:18
# 🎥 Rendering lidars for split test 🎥 ━╸━━━━ 25/80(31.2%) 1.41    0:00:… 0:00:18
# 🎥 Rendering lidars for split test 🎥 ━╸━━━━ 25/80(31.2%) 1.41    0:00:… 0:00:18
# 🎥 Rendering lidars for split test 🎥 ━╸━━━━ 25/80(31.2%) 1.41    0:00:… 0:00:18
# 🎥 Rendering lidars for split test 🎥 ━╸━━━━ 25/80(31.2%) 1.41    0:00:… 0:00:18
# 🎥 Rendering lidars for split test 🎥 ━╸━━━━ 26/80(32.5%) 1.41    0:00:… 0:00:18
# 🎥 Rendering lidars for split test 🎥 ━╸━━━━ 26/80(32.5%) 1.41    0:00:… 0:00:18
# 🎥 Rendering lidars for split test 🎥 ━╸━━━━ 26/80(32.5%) 1.41    0:00:… 0:00:18
# 🎥 Rendering lidars for split test 🎥 ━╸━━━━ 26/80(32.5%) 1.41    0:00:… 0:00:18
# 🎥 Rendering lidars for split test 🎥 ━╸━━━━ 26/80(32.5%) 1.41    0:00:… 0:00:19
# 🎥 Rendering lidars for split test 🎥 ━━╺━━━ 27/80(33.8%) 1.42    0:00:… 0:00:19
# 🎥 Rendering lidars for split test 🎥 ━━╺━━━ 27/80(33.8%) 1.42    0:00:… 0:00:19
# 🎥 Rendering lidars for split test 🎥 ━━╺━━━ 27/80(33.8%) 1.42    0:00:… 0:00:19
# 🎥 Rendering lidars for split test 🎥 ━━╺━━━ 27/80(33.8%) 1.42    0:00:… 0:00:19
# 🎥 Rendering lidars for split test 🎥 ━━╺━━━ 27/80(33.8%) 1.42    0:00:… 0:00:19
# 🎥 Rendering lidars for split test 🎥 ━━╺━━━ 27/80(33.8%) 1.42    0:00:… 0:00:19
# 🎥 Rendering lidars for split test 🎥 ━━╺━━━ 27/80(33.8%) 1.42    0:00:… 0:00:19
# 🎥 Rendering lidars for split test 🎥 ━━╺━━━ 28/80(35.0%) 1.42    0:00:… 0:00:19
# 🎥 Rendering lidars for split test 🎥 ━━╺━━━ 28/80(35.0%) 1.42    0:00:… 0:00:19
# 🎥 Rendering lidars for split test 🎥 ━━╺━━━ 28/80(35.0%) 1.42    0:00:… 0:00:20
# 🎥 Rendering lidars for split test 🎥 ━━╺━━━ 28/80(35.0%) 1.42    0:00:… 0:00:20
# 🎥 Rendering lidars for split test 🎥 ━━╺━━━ 28/80(35.0%) 1.42    0:00:… 0:00:20
# 🎥 Rendering lidars for split test 🎥 ━━╺━━━ 28/80(35.0%) 1.42    0:00:… 0:00:20
# 🎥 Rendering lidars for split test 🎥 ━━╺━━━ 28/80(35.0%) 1.42    0:00:… 0:00:20
# 🎥 Rendering lidars for split test 🎥 ━━╺━━━ 29/80(36.2%) 1.42    0:00:… 0:00:20
# 🎥 Rendering lidars for split test 🎥 ━━╺━━━ 29/80(36.2%) 1.42    0:00:… 0:00:20
# 🎥 Rendering lidars for split test 🎥 ━━╺━━━ 29/80(36.2%) 1.42    0:00:… 0:00:20
# 🎥 Rendering lidars for split test 🎥 ━━╺━━━ 29/80(36.2%) 1.42    0:00:… 0:00:20
# 🎥 Rendering lidars for split test 🎥 ━━╺━━━ 29/80(36.2%) 1.42    0:00:… 0:00:20
# 🎥 Rendering lidars for split test 🎥 ━━╺━━━ 29/80(36.2%) 1.42    0:00:… 0:00:21
# 🎥 Rendering lidars for split test 🎥 ━━╺━━━ 29/80(36.2%) 1.42    0:00:… 0:00:21
# 🎥 Rendering lidars for split test 🎥 ━━╺━━━ 30/80(37.5%) 1.42    0:00:… 0:00:21
# 🎥 Rendering lidars for split test 🎥 ━━╺━━━ 30/80(37.5%) 1.42    0:00:… 0:00:21
# 🎥 Rendering lidars for split test 🎥 ━━╺━━━ 30/80(37.5%) 1.42    0:00:… 0:00:21
# 🎥 Rendering lidars for split test 🎥 ━━╺━━━ 30/80(37.5%) 1.42    0:00:… 0:00:21
# 🎥 Rendering lidars for split test 🎥 ━━╺━━━ 30/80(37.5%) 1.42    0:00:… 0:00:21
# 🎥 Rendering lidars for split test 🎥 ━━╺━━━ 30/80(37.5%) 1.42    0:00:… 0:00:21
# 🎥 Rendering lidars for split test 🎥 ━━╺━━━ 30/80(37.5%) 1.42    0:00:… 0:00:21
# 🎥 Rendering lidars for split test 🎥 ━━╺━━━ 31/80(38.8%) 1.42    0:00:… 0:00:21
# 🎥 Rendering lidars for split test 🎥 ━━╺━━━ 31/80(38.8%) 1.42    0:00:… 0:00:22
# 🎥 Rendering lidars for split test 🎥 ━━╺━━━ 31/80(38.8%) 1.42    0:00:… 0:00:22
# 🎥 Rendering lidars for split test 🎥 ━━╺━━━ 31/80(38.8%) 1.42    0:00:… 0:00:22
# 🎥 Rendering lidars for split test 🎥 ━━╺━━━ 31/80(38.8%) 1.42    0:00:… 0:00:22
# 🎥 Rendering lidars for split test 🎥 ━━╺━━━ 31/80(38.8%) 1.42    0:00:… 0:00:22
# 🎥 Rendering lidars for split test 🎥 ━━╺━━━ 31/80(38.8%) 1.42    0:00:… 0:00:22
# 🎥 Rendering lidars for split test 🎥 ━━╺━━━ 32/80(40.0%) 1.42    0:00:… 0:00:22
# 🎥 Rendering lidars for split test 🎥 ━━╺━━━ 32/80(40.0%) 1.42    0:00:… 0:00:22
# 🎥 Rendering lidars for split test 🎥 ━━╺━━━ 32/80(40.0%) 1.42    0:00:… 0:00:22
# 🎥 Rendering lidars for split test 🎥 ━━╺━━━ 32/80(40.0%) 1.42    0:00:… 0:00:22
# 🎥 Rendering lidars for split test 🎥 ━━╺━━━ 32/80(40.0%) 1.42    0:00:… 0:00:23
# 🎥 Rendering lidars for split test 🎥 ━━╺━━━ 32/80(40.0%) 1.42    0:00:… 0:00:23
# 🎥 Rendering lidars for split test 🎥 ━━╺━━━ 32/80(40.0%) 1.42    0:00:… 0:00:23
# 🎥 Rendering lidars for split test 🎥 ━━╺━━━ 33/80(41.2%) 1.42    0:00:… 0:00:23
# 🎥 Rendering lidars for split test 🎥 ━━╺━━━ 33/80(41.2%) 1.42    0:00:… 0:00:23
# 🎥 Rendering lidars for split test 🎥 ━━╺━━━ 33/80(41.2%) 1.42    0:00:… 0:00:23
# 🎥 Rendering lidars for split test 🎥 ━━╺━━━ 33/80(41.2%) 1.42    0:00:… 0:00:23
# 🎥 Rendering lidars for split test 🎥 ━━╺━━━ 33/80(41.2%) 1.42    0:00:… 0:00:23
# 🎥 Rendering lidars for split test 🎥 ━━╺━━━ 33/80(41.2%) 1.42    0:00:… 0:00:23
# 🎥 Rendering lidars for split test 🎥 ━━╺━━━ 33/80(41.2%) 1.42    0:00:… 0:00:24
# 🎥 Rendering lidars for split test 🎥 ━━╸━━━ 34/80(42.5%) 1.42    0:00:… 0:00:24
# 🎥 Rendering lidars for split test 🎥 ━━╸━━━ 34/80(42.5%) 1.42    0:00:… 0:00:24
# 🎥 Rendering lidars for split test 🎥 ━━╸━━━ 34/80(42.5%) 1.42    0:00:… 0:00:24
# 🎥 Rendering lidars for split test 🎥 ━━╸━━━ 34/80(42.5%) 1.42    0:00:… 0:00:24
# 🎥 Rendering lidars for split test 🎥 ━━╸━━━ 34/80(42.5%) 1.42    0:00:… 0:00:24
# 🎥 Rendering lidars for split test 🎥 ━━╸━━━ 34/80(42.5%) 1.42    0:00:… 0:00:24
# 🎥 Rendering lidars for split test 🎥 ━━╸━━━ 34/80(42.5%) 1.42    0:00:… 0:00:24
# 🎥 Rendering lidars for split test 🎥 ━━╸━━━ 35/80(43.8%) 1.42    0:00:… 0:00:24
# 🎥 Rendering lidars for split test 🎥 ━━╸━━━ 35/80(43.8%) 1.42    0:00:… 0:00:24
# 🎥 Rendering lidars for split test 🎥 ━━╸━━━ 35/80(43.8%) 1.42    0:00:… 0:00:25
# 🎥 Rendering lidars for split test 🎥 ━━╸━━━ 35/80(43.8%) 1.42    0:00:… 0:00:25
# 🎥 Rendering lidars for split test 🎥 ━━╸━━━ 35/80(43.8%) 1.42    0:00:… 0:00:25
# 🎥 Rendering lidars for split test 🎥 ━━╸━━━ 35/80(43.8%) 1.42    0:00:… 0:00:25
# 🎥 Rendering lidars for split test 🎥 ━━╸━━━ 36/80(45.0%) 1.42    0:00:… 0:00:25
# 🎥 Rendering lidars for split test 🎥 ━━╸━━━ 36/80(45.0%) 1.42    0:00:… 0:00:25
# 🎥 Rendering lidars for split test 🎥 ━━╸━━━ 36/80(45.0%) 1.42    0:00:… 0:00:25
# 🎥 Rendering lidars for split test 🎥 ━━╸━━━ 36/80(45.0%) 1.42    0:00:… 0:00:25
# 🎥 Rendering lidars for split test 🎥 ━━╸━━━ 36/80(45.0%) 1.42    0:00:… 0:00:25
# 🎥 Rendering lidars for split test 🎥 ━━╸━━━ 36/80(45.0%) 1.42    0:00:… 0:00:25
# 🎥 Rendering lidars for split test 🎥 ━━╸━━━ 36/80(45.0%) 1.42    0:00:… 0:00:26
# 🎥 Rendering lidars for split test 🎥 ━━╸━━━ 37/80(46.2%) 1.42    0:00:… 0:00:26
# 🎥 Rendering lidars for split test 🎥 ━━╸━━━ 37/80(46.2%) 1.42    0:00:… 0:00:26
# 🎥 Rendering lidars for split test 🎥 ━━╸━━━ 37/80(46.2%) 1.42    0:00:… 0:00:26
# 🎥 Rendering lidars for split test 🎥 ━━╸━━━ 37/80(46.2%) 1.42    0:00:… 0:00:26
# 🎥 Rendering lidars for split test 🎥 ━━╸━━━ 37/80(46.2%) 1.42    0:00:… 0:00:26
# 🎥 Rendering lidars for split test 🎥 ━━╸━━━ 37/80(46.2%) 1.42    0:00:… 0:00:26
# 🎥 Rendering lidars for split test 🎥 ━━╸━━━ 37/80(46.2%) 1.42    0:00:… 0:00:26
# 🎥 Rendering lidars for split test 🎥 ━━╸━━━ 38/80(47.5%) 1.42    0:00:… 0:00:26
# 🎥 Rendering lidars for split test 🎥 ━━╸━━━ 38/80(47.5%) 1.42    0:00:… 0:00:26
# 🎥 Rendering lidars for split test 🎥 ━━╸━━━ 38/80(47.5%) 1.42    0:00:… 0:00:27
# 🎥 Rendering lidars for split test 🎥 ━━╸━━━ 38/80(47.5%) 1.42    0:00:… 0:00:27
# 🎥 Rendering lidars for split test 🎥 ━━╸━━━ 38/80(47.5%) 1.42    0:00:… 0:00:27
# 🎥 Rendering lidars for split test 🎥 ━━╸━━━ 38/80(47.5%) 1.42    0:00:… 0:00:27
# 🎥 Rendering lidars for split test 🎥 ━━╸━━━ 39/80(48.8%) 1.43    0:00:… 0:00:27
# 🎥 Rendering lidars for split test 🎥 ━━╸━━━ 39/80(48.8%) 1.43    0:00:… 0:00:27
# 🎥 Rendering lidars for split test 🎥 ━━╸━━━ 39/80(48.8%) 1.43    0:00:… 0:00:27
# 🎥 Rendering lidars for split test 🎥 ━━╸━━━ 39/80(48.8%) 1.43    0:00:… 0:00:27
# 🎥 Rendering lidars for split test 🎥 ━━╸━━━ 39/80(48.8%) 1.43    0:00:… 0:00:27
# 🎥 Rendering lidars for split test 🎥 ━━╸━━━ 39/80(48.8%) 1.43    0:00:… 0:00:27
# 🎥 Rendering lidars for split test 🎥 ━━╸━━━ 39/80(48.8%) 1.43    0:00:… 0:00:28
# 🎥 Rendering lidars for split test 🎥 ━━━╺━━ 40/80(50.0%) 1.43    0:00:… 0:00:28
# 🎥 Rendering lidars for split test 🎥 ━━━╺━━ 40/80(50.0%) 1.43    0:00:… 0:00:28
# 🎥 Rendering lidars for split test 🎥 ━━━╺━━ 40/80(50.0%) 1.43    0:00:… 0:00:28
# 🎥 Rendering lidars for split test 🎥 ━━━╺━━ 40/80(50.0%) 1.43    0:00:… 0:00:28
# 🎥 Rendering lidars for split test 🎥 ━━━╺━━ 40/80(50.0%) 1.43    0:00:… 0:00:28
# 🎥 Rendering lidars for split test 🎥 ━━━╺━━ 40/80(50.0%) 1.43    0:00:… 0:00:28
# 🎥 Rendering lidars for split test 🎥 ━━━╺━━ 40/80(50.0%) 1.43    0:00:… 0:00:28
# 🎥 Rendering lidars for split test 🎥 ━━━╺━━ 41/80(51.2%) 1.43    0:00:… 0:00:28
# 🎥 Rendering lidars for split test 🎥 ━━━╺━━ 41/80(51.2%) 1.43    0:00:… 0:00:28
# 🎥 Rendering lidars for split test 🎥 ━━━╺━━ 41/80(51.2%) 1.43    0:00:… 0:00:29
# 🎥 Rendering lidars for split test 🎥 ━━━╺━━ 41/80(51.2%) 1.43    0:00:… 0:00:29
# 🎥 Rendering lidars for split test 🎥 ━━━╺━━ 41/80(51.2%) 1.43    0:00:… 0:00:29
# 🎥 Rendering lidars for split test 🎥 ━━━╺━━ 41/80(51.2%) 1.43    0:00:… 0:00:29
# 🎥 Rendering lidars for split test 🎥 ━━━╺━━ 41/80(51.2%) 1.43    0:00:… 0:00:29
# 🎥 Rendering lidars for split test 🎥 ━━━╺━━ 42/80(52.5%) 1.43    0:00:… 0:00:29
# 🎥 Rendering lidars for split test 🎥 ━━━╺━━ 42/80(52.5%) 1.43    0:00:… 0:00:29
# 🎥 Rendering lidars for split test 🎥 ━━━╺━━ 42/80(52.5%) 1.43    0:00:… 0:00:29
# 🎥 Rendering lidars for split test 🎥 ━━━╺━━ 42/80(52.5%) 1.43    0:00:… 0:00:29
# 🎥 Rendering lidars for split test 🎥 ━━━╺━━ 42/80(52.5%) 1.43    0:00:… 0:00:30
# 🎥 Rendering lidars for split test 🎥 ━━━╺━━ 42/80(52.5%) 1.43    0:00:… 0:00:30
# 🎥 Rendering lidars for split test 🎥 ━━━╺━━ 43/80(53.8%) 1.43    0:00:… 0:00:30
# 🎥 Rendering lidars for split test 🎥 ━━━╺━━ 43/80(53.8%) 1.43    0:00:… 0:00:30
# 🎥 Rendering lidars for split test 🎥 ━━━╺━━ 43/80(53.8%) 1.43    0:00:… 0:00:30
# 🎥 Rendering lidars for split test 🎥 ━━━╺━━ 43/80(53.8%) 1.43    0:00:… 0:00:30
# 🎥 Rendering lidars for split test 🎥 ━━━╺━━ 43/80(53.8%) 1.43    0:00:… 0:00:30
# 🎥 Rendering lidars for split test 🎥 ━━━╺━━ 43/80(53.8%) 1.43    0:00:… 0:00:30
# 🎥 Rendering lidars for split test 🎥 ━━━╺━━ 43/80(53.8%) 1.43    0:00:… 0:00:30
# 🎥 Rendering lidars for split test 🎥 ━━━╺━━ 44/80(55.0%) 1.43    0:00:… 0:00:30
# 🎥 Rendering lidars for split test 🎥 ━━━╺━━ 44/80(55.0%) 1.43    0:00:… 0:00:31
# 🎥 Rendering lidars for split test 🎥 ━━━╺━━ 44/80(55.0%) 1.43    0:00:… 0:00:31
# 🎥 Rendering lidars for split test 🎥 ━━━╺━━ 44/80(55.0%) 1.43    0:00:… 0:00:31
# 🎥 Rendering lidars for split test 🎥 ━━━╺━━ 44/80(55.0%) 1.43    0:00:… 0:00:31
# 🎥 Rendering lidars for split test 🎥 ━━━╺━━ 44/80(55.0%) 1.43    0:00:… 0:00:31
# 🎥 Rendering lidars for split test 🎥 ━━━╺━━ 45/80(56.2%) 1.44    0:00:… 0:00:31
# 🎥 Rendering lidars for split test 🎥 ━━━╺━━ 45/80(56.2%) 1.44    0:00:… 0:00:31
# 🎥 Rendering lidars for split test 🎥 ━━━╺━━ 45/80(56.2%) 1.44    0:00:… 0:00:31
# 🎥 Rendering lidars for split test 🎥 ━━━╺━━ 45/80(56.2%) 1.44    0:00:… 0:00:31
# 🎥 Rendering lidars for split test 🎥 ━━━╺━━ 45/80(56.2%) 1.44    0:00:… 0:00:31
# 🎥 Rendering lidars for split test 🎥 ━━━╺━━ 45/80(56.2%) 1.44    0:00:… 0:00:32
# 🎥 Rendering lidars for split test 🎥 ━━━╺━━ 46/80(57.5%) 1.44    0:00:… 0:00:32
# 🎥 Rendering lidars for split test 🎥 ━━━╺━━ 46/80(57.5%) 1.44    0:00:… 0:00:32
# 🎥 Rendering lidars for split test 🎥 ━━━╺━━ 46/80(57.5%) 1.44    0:00:… 0:00:32
# 🎥 Rendering lidars for split test 🎥 ━━━╺━━ 46/80(57.5%) 1.44    0:00:… 0:00:32
# 🎥 Rendering lidars for split test 🎥 ━━━╺━━ 46/80(57.5%) 1.44    0:00:… 0:00:32
# 🎥 Rendering lidars for split test 🎥 ━━━╺━━ 46/80(57.5%) 1.44    0:00:… 0:00:32
# 🎥 Rendering lidars for split test 🎥 ━━━╺━━ 46/80(57.5%) 1.44    0:00:… 0:00:32
# 🎥 Rendering lidars for split test 🎥 ━━━╸━━ 47/80(58.8%) 1.44    0:00:… 0:00:32
# 🎥 Rendering lidars for split test 🎥 ━━━╸━━ 47/80(58.8%) 1.44    0:00:… 0:00:32
# 🎥 Rendering lidars for split test 🎥 ━━━╸━━ 47/80(58.8%) 1.44    0:00:… 0:00:33
# 🎥 Rendering lidars for split test 🎥 ━━━╸━━ 47/80(58.8%) 1.44    0:00:… 0:00:33
# 🎥 Rendering lidars for split test 🎥 ━━━╸━━ 47/80(58.8%) 1.44    0:00:… 0:00:33
# 🎥 Rendering lidars for split test 🎥 ━━━╸━━ 47/80(58.8%) 1.44    0:00:… 0:00:33
# 🎥 Rendering lidars for split test 🎥 ━━━╸━━ 47/80(58.8%) 1.44    0:00:… 0:00:33
# 🎥 Rendering lidars for split test 🎥 ━━━╸━━ 48/80(60.0%) 1.44    0:00:… 0:00:33
# 🎥 Rendering lidars for split test 🎥 ━━━╸━━ 48/80(60.0%) 1.44    0:00:… 0:00:33
# 🎥 Rendering lidars for split test 🎥 ━━━╸━━ 48/80(60.0%) 1.44    0:00:… 0:00:33
# 🎥 Rendering lidars for split test 🎥 ━━━╸━━ 48/80(60.0%) 1.44    0:00:… 0:00:33
# 🎥 Rendering lidars for split test 🎥 ━━━╸━━ 48/80(60.0%) 1.44    0:00:… 0:00:33
# 🎥 Rendering lidars for split test 🎥 ━━━╸━━ 48/80(60.0%) 1.44    0:00:… 0:00:34
# 🎥 Rendering lidars for split test 🎥 ━━━╸━━ 49/80(61.3%) 1.45    0:00:… 0:00:34
# 🎥 Rendering lidars for split test 🎥 ━━━╸━━ 49/80(61.3%) 1.45    0:00:… 0:00:34
# 🎥 Rendering lidars for split test 🎥 ━━━╸━━ 49/80(61.3%) 1.45    0:00:… 0:00:34
# 🎥 Rendering lidars for split test 🎥 ━━━╸━━ 49/80(61.3%) 1.45    0:00:… 0:00:34
# 🎥 Rendering lidars for split test 🎥 ━━━╸━━ 49/80(61.3%) 1.45    0:00:… 0:00:34
# 🎥 Rendering lidars for split test 🎥 ━━━╸━━ 49/80(61.3%) 1.45    0:00:… 0:00:34
# 🎥 Rendering lidars for split test 🎥 ━━━╸━━ 49/80(61.3%) 1.45    0:00:… 0:00:34
# 🎥 Rendering lidars for split test 🎥 ━━━╸━━ 50/80(62.5%) 1.45    0:00:… 0:00:34
# 🎥 Rendering lidars for split test 🎥 ━━━╸━━ 50/80(62.5%) 1.45    0:00:… 0:00:34
# 🎥 Rendering lidars for split test 🎥 ━━━╸━━ 50/80(62.5%) 1.45    0:00:… 0:00:35
# 🎥 Rendering lidars for split test 🎥 ━━━╸━━ 50/80(62.5%) 1.45    0:00:… 0:00:35
# 🎥 Rendering lidars for split test 🎥 ━━━╸━━ 50/80(62.5%) 1.45    0:00:… 0:00:35
# 🎥 Rendering lidars for split test 🎥 ━━━╸━━ 50/80(62.5%) 1.45    0:00:… 0:00:35
# 🎥 Rendering lidars for split test 🎥 ━━━╸━━ 50/80(62.5%) 1.45    0:00:… 0:00:35
# 🎥 Rendering lidars for split test 🎥 ━━━╸━━ 51/80(63.7%) 1.45    0:00:… 0:00:35
# 🎥 Rendering lidars for split test 🎥 ━━━╸━━ 51/80(63.7%) 1.45    0:00:… 0:00:35
# 🎥 Rendering lidars for split test 🎥 ━━━╸━━ 51/80(63.7%) 1.45    0:00:… 0:00:35
# 🎥 Rendering lidars for split test 🎥 ━━━╸━━ 51/80(63.7%) 1.45    0:00:… 0:00:35
# 🎥 Rendering lidars for split test 🎥 ━━━╸━━ 51/80(63.7%) 1.45    0:00:… 0:00:36
# 🎥 Rendering lidars for split test 🎥 ━━━╸━━ 51/80(63.7%) 1.45    0:00:… 0:00:36
# 🎥 Rendering lidars for split test 🎥 ━━━╸━━ 52/80(65.0%) 1.46    0:00:… 0:00:36
# 🎥 Rendering lidars for split test 🎥 ━━━╸━━ 52/80(65.0%) 1.46    0:00:… 0:00:36
# 🎥 Rendering lidars for split test 🎥 ━━━╸━━ 52/80(65.0%) 1.46    0:00:… 0:00:36
# 🎥 Rendering lidars for split test 🎥 ━━━╸━━ 52/80(65.0%) 1.46    0:00:… 0:00:36
# 🎥 Rendering lidars for split test 🎥 ━━━╸━━ 52/80(65.0%) 1.46    0:00:… 0:00:36
# 🎥 Rendering lidars for split test 🎥 ━━━╸━━ 52/80(65.0%) 1.46    0:00:… 0:00:36
# 🎥 Rendering lidars for split test 🎥 ━━━╸━━ 52/80(65.0%) 1.46    0:00:… 0:00:36
# 🎥 Rendering lidars for split test 🎥 ━━━╸━━ 53/80(66.2%) 1.46    0:00:… 0:00:36
# 🎥 Rendering lidars for split test 🎥 ━━━╸━━ 53/80(66.2%) 1.46    0:00:… 0:00:37
# 🎥 Rendering lidars for split test 🎥 ━━━╸━━ 53/80(66.2%) 1.46    0:00:… 0:00:37
# 🎥 Rendering lidars for split test 🎥 ━━━╸━━ 53/80(66.2%) 1.46    0:00:… 0:00:37
# 🎥 Rendering lidars for split test 🎥 ━━━╸━━ 53/80(66.2%) 1.46    0:00:… 0:00:37
# 🎥 Rendering lidars for split test 🎥 ━━━╸━━ 53/80(66.2%) 1.46    0:00:… 0:00:37
# 🎥 Rendering lidars for split test 🎥 ━━━━╺━ 54/80(67.5%) 1.46    0:00:… 0:00:37
# 🎥 Rendering lidars for split test 🎥 ━━━━╺━ 54/80(67.5%) 1.46    0:00:… 0:00:37
# 🎥 Rendering lidars for split test 🎥 ━━━━╺━ 54/80(67.5%) 1.46    0:00:… 0:00:37
# 🎥 Rendering lidars for split test 🎥 ━━━━╺━ 54/80(67.5%) 1.46    0:00:… 0:00:37
# 🎥 Rendering lidars for split test 🎥 ━━━━╺━ 54/80(67.5%) 1.46    0:00:… 0:00:37
# 🎥 Rendering lidars for split test 🎥 ━━━━╺━ 54/80(67.5%) 1.46    0:00:… 0:00:38
# 🎥 Rendering lidars for split test 🎥 ━━━━╺━ 54/80(67.5%) 1.46    0:00:… 0:00:38
# 🎥 Rendering lidars for split test 🎥 ━━━━╺━ 55/80(68.8%) 1.46    0:00:… 0:00:38
# 🎥 Rendering lidars for split test 🎥 ━━━━╺━ 55/80(68.8%) 1.46    0:00:… 0:00:38
# 🎥 Rendering lidars for split test 🎥 ━━━━╺━ 55/80(68.8%) 1.46    0:00:… 0:00:38
# 🎥 Rendering lidars for split test 🎥 ━━━━╺━ 55/80(68.8%) 1.46    0:00:… 0:00:38
# 🎥 Rendering lidars for split test 🎥 ━━━━╺━ 55/80(68.8%) 1.46    0:00:… 0:00:38
# 🎥 Rendering lidars for split test 🎥 ━━━━╺━ 55/80(68.8%) 1.46    0:00:… 0:00:38
# 🎥 Rendering lidars for split test 🎥 ━━━━╺━ 56/80(70.0%) 1.46    0:00:… 0:00:38
# 🎥 Rendering lidars for split test 🎥 ━━━━╺━ 56/80(70.0%) 1.46    0:00:… 0:00:38
# 🎥 Rendering lidars for split test 🎥 ━━━━╺━ 56/80(70.0%) 1.46    0:00:… 0:00:39
# 🎥 Rendering lidars for split test 🎥 ━━━━╺━ 56/80(70.0%) 1.46    0:00:… 0:00:39
# 🎥 Rendering lidars for split test 🎥 ━━━━╺━ 56/80(70.0%) 1.46    0:00:… 0:00:39
# 🎥 Rendering lidars for split test 🎥 ━━━━╺━ 56/80(70.0%) 1.46    0:00:… 0:00:39
# 🎥 Rendering lidars for split test 🎥 ━━━━╺━ 56/80(70.0%) 1.46    0:00:… 0:00:39
# 🎥 Rendering lidars for split test 🎥 ━━━━╺━ 57/80(71.2%) 1.46    0:00:… 0:00:39
# 🎥 Rendering lidars for split test 🎥 ━━━━╺━ 57/80(71.2%) 1.46    0:00:… 0:00:39
# 🎥 Rendering lidars for split test 🎥 ━━━━╺━ 57/80(71.2%) 1.46    0:00:… 0:00:39
# 🎥 Rendering lidars for split test 🎥 ━━━━╺━ 57/80(71.2%) 1.46    0:00:… 0:00:39
# 🎥 Rendering lidars for split test 🎥 ━━━━╺━ 57/80(71.2%) 1.46    0:00:… 0:00:39
# 🎥 Rendering lidars for split test 🎥 ━━━━╺━ 57/80(71.2%) 1.46    0:00:… 0:00:40
# 🎥 Rendering lidars for split test 🎥 ━━━━╺━ 57/80(71.2%) 1.46    0:00:… 0:00:40
# 🎥 Rendering lidars for split test 🎥 ━━━━╺━ 58/80(72.5%) 1.46    0:00:… 0:00:40
# 🎥 Rendering lidars for split test 🎥 ━━━━╺━ 58/80(72.5%) 1.46    0:00:… 0:00:40
# 🎥 Rendering lidars for split test 🎥 ━━━━╺━ 58/80(72.5%) 1.46    0:00:… 0:00:40
# 🎥 Rendering lidars for split test 🎥 ━━━━╺━ 58/80(72.5%) 1.46    0:00:… 0:00:40
# 🎥 Rendering lidars for split test 🎥 ━━━━╺━ 58/80(72.5%) 1.46    0:00:… 0:00:40
# 🎥 Rendering lidars for split test 🎥 ━━━━╺━ 58/80(72.5%) 1.46    0:00:… 0:00:40
# 🎥 Rendering lidars for split test 🎥 ━━━━╺━ 58/80(72.5%) 1.46    0:00:… 0:00:40
# 🎥 Rendering lidars for split test 🎥 ━━━━╺━ 59/80(73.8%) 1.46    0:00:… 0:00:40
# 🎥 Rendering lidars for split test 🎥 ━━━━╺━ 59/80(73.8%) 1.46    0:00:… 0:00:41
# 🎥 Rendering lidars for split test 🎥 ━━━━╺━ 59/80(73.8%) 1.46    0:00:… 0:00:41
# 🎥 Rendering lidars for split test 🎥 ━━━━╺━ 59/80(73.8%) 1.46    0:00:… 0:00:41
# 🎥 Rendering lidars for split test 🎥 ━━━━╺━ 59/80(73.8%) 1.46    0:00:… 0:00:41
# 🎥 Rendering lidars for split test 🎥 ━━━━╺━ 59/80(73.8%) 1.46    0:00:… 0:00:41
# 🎥 Rendering lidars for split test 🎥 ━━━━╺━ 59/80(73.8%) 1.46    0:00:… 0:00:41
# 🎥 Rendering lidars for split test 🎥 ━━━━╸━ 60/80(75.0%) 1.46    0:00:… 0:00:41
# 🎥 Rendering lidars for split test 🎥 ━━━━╸━ 60/80(75.0%) 1.46    0:00:… 0:00:41
# 🎥 Rendering lidars for split test 🎥 ━━━━╸━ 60/80(75.0%) 1.46    0:00:… 0:00:41
# 🎥 Rendering lidars for split test 🎥 ━━━━╸━ 60/80(75.0%) 1.46    0:00:… 0:00:42
# 🎥 Rendering lidars for split test 🎥 ━━━━╸━ 60/80(75.0%) 1.46    0:00:… 0:00:42
# 🎥 Rendering lidars for split test 🎥 ━━━━╸━ 60/80(75.0%) 1.46    0:00:… 0:00:42
# 🎥 Rendering lidars for split test 🎥 ━━━━╸━ 60/80(75.0%) 1.46    0:00:… 0:00:42
# 🎥 Rendering lidars for split test 🎥 ━━━━╸━ 61/80(76.2%) 1.46    0:00:… 0:00:42
# 🎥 Rendering lidars for split test 🎥 ━━━━╸━ 61/80(76.2%) 1.46    0:00:… 0:00:42
# 🎥 Rendering lidars for split test 🎥 ━━━━╸━ 61/80(76.2%) 1.46    0:00:… 0:00:42
# 🎥 Rendering lidars for split test 🎥 ━━━━╸━ 61/80(76.2%) 1.46    0:00:… 0:00:42
# 🎥 Rendering lidars for split test 🎥 ━━━━╸━ 61/80(76.2%) 1.46    0:00:… 0:00:42
# 🎥 Rendering lidars for split test 🎥 ━━━━╸━ 61/80(76.2%) 1.46    0:00:… 0:00:42
# 🎥 Rendering lidars for split test 🎥 ━━━━╸━ 62/80(77.5%) 1.47    0:00:… 0:00:43
# 🎥 Rendering lidars for split test 🎥 ━━━━╸━ 62/80(77.5%) 1.47    0:00:… 0:00:43
# 🎥 Rendering lidars for split test 🎥 ━━━━╸━ 62/80(77.5%) 1.47    0:00:… 0:00:43
# 🎥 Rendering lidars for split test 🎥 ━━━━╸━ 62/80(77.5%) 1.47    0:00:… 0:00:43
# 🎥 Rendering lidars for split test 🎥 ━━━━╸━ 62/80(77.5%) 1.47    0:00:… 0:00:43
# 🎥 Rendering lidars for split test 🎥 ━━━━╸━ 62/80(77.5%) 1.47    0:00:… 0:00:43
# 🎥 Rendering lidars for split test 🎥 ━━━━╸━ 63/80(78.8%) 1.47    0:00:… 0:00:43
# 🎥 Rendering lidars for split test 🎥 ━━━━╸━ 63/80(78.8%) 1.47    0:00:… 0:00:43
# 🎥 Rendering lidars for split test 🎥 ━━━━╸━ 63/80(78.8%) 1.47    0:00:… 0:00:43
# 🎥 Rendering lidars for split test 🎥 ━━━━╸━ 63/80(78.8%) 1.47    0:00:… 0:00:43
# 🎥 Rendering lidars for split test 🎥 ━━━━╸━ 63/80(78.8%) 1.47    0:00:… 0:00:44
# 🎥 Rendering lidars for split test 🎥 ━━━━╸━ 63/80(78.8%) 1.47    0:00:… 0:00:44
# 🎥 Rendering lidars for split test 🎥 ━━━━╸━ 63/80(78.8%) 1.47    0:00:… 0:00:44
# 🎥 Rendering lidars for split test 🎥 ━━━━╸━ 64/80(80.0%) 1.47    0:00:… 0:00:44
# 🎥 Rendering lidars for split test 🎥 ━━━━╸━ 64/80(80.0%) 1.47    0:00:… 0:00:44
# 🎥 Rendering lidars for split test 🎥 ━━━━╸━ 64/80(80.0%) 1.47    0:00:… 0:00:44
# 🎥 Rendering lidars for split test 🎥 ━━━━╸━ 64/80(80.0%) 1.47    0:00:… 0:00:44
# 🎥 Rendering lidars for split test 🎥 ━━━━╸━ 64/80(80.0%) 1.47    0:00:… 0:00:44
# 🎥 Rendering lidars for split test 🎥 ━━━━╸━ 64/80(80.0%) 1.47    0:00:… 0:00:44
# 🎥 Rendering lidars for split test 🎥 ━━━━╸━ 64/80(80.0%) 1.47    0:00:… 0:00:44
# 🎥 Rendering lidars for split test 🎥 ━━━━╸━ 65/80(81.2%) 1.47    0:00:… 0:00:45
# 🎥 Rendering lidars for split test 🎥 ━━━━╸━ 65/80(81.2%) 1.47    0:00:… 0:00:45
# 🎥 Rendering lidars for split test 🎥 ━━━━╸━ 65/80(81.2%) 1.47    0:00:… 0:00:45
# 🎥 Rendering lidars for split test 🎥 ━━━━╸━ 65/80(81.2%) 1.47    0:00:… 0:00:45
# 🎥 Rendering lidars for split test 🎥 ━━━━╸━ 65/80(81.2%) 1.47    0:00:… 0:00:45
# 🎥 Rendering lidars for split test 🎥 ━━━━╸━ 65/80(81.2%) 1.47    0:00:… 0:00:45
# 🎥 Rendering lidars for split test 🎥 ━━━━╸━ 65/80(81.2%) 1.47    0:00:… 0:00:45
# 🎥 Rendering lidars for split test 🎥 ━━━━╸━ 66/80(82.5%) 1.47    0:00:… 0:00:45
# 🎥 Rendering lidars for split test 🎥 ━━━━╸━ 66/80(82.5%) 1.47    0:00:… 0:00:45
# 🎥 Rendering lidars for split test 🎥 ━━━━╸━ 66/80(82.5%) 1.47    0:00:… 0:00:45
# 🎥 Rendering lidars for split test 🎥 ━━━━╸━ 66/80(82.5%) 1.47    0:00:… 0:00:46
# 🎥 Rendering lidars for split test 🎥 ━━━━╸━ 66/80(82.5%) 1.47    0:00:… 0:00:46
# 🎥 Rendering lidars for split test 🎥 ━━━━╸━ 66/80(82.5%) 1.47    0:00:… 0:00:46
# 🎥 Rendering lidars for split test 🎥 ━━━━╸━ 66/80(82.5%) 1.47    0:00:… 0:00:46
# 🎥 Rendering lidars for split test 🎥 ━━━━╸━ 66/80(82.5%) 1.47    0:00:… 0:00:46
# 🎥 Rendering lidars for split test 🎥 ━━━━━╺ 67/80(83.8%) 1.46    0:00:… 0:00:46
# 🎥 Rendering lidars for split test 🎥 ━━━━━╺ 67/80(83.8%) 1.46    0:00:… 0:00:46
# 🎥 Rendering lidars for split test 🎥 ━━━━━╺ 67/80(83.8%) 1.46    0:00:… 0:00:46
# 🎥 Rendering lidars for split test 🎥 ━━━━━╺ 67/80(83.8%) 1.46    0:00:… 0:00:46
# 🎥 Rendering lidars for split test 🎥 ━━━━━╺ 67/80(83.8%) 1.46    0:00:… 0:00:46
# 🎥 Rendering lidars for split test 🎥 ━━━━━╺ 67/80(83.8%) 1.46    0:00:… 0:00:47
# 🎥 Rendering lidars for split test 🎥 ━━━━━╺ 67/80(83.8%) 1.46    0:00:… 0:00:47
# 🎥 Rendering lidars for split test 🎥 ━━━━━╺ 68/80(85.0%) 1.46    0:00:… 0:00:47
# 🎥 Rendering lidars for split test 🎥 ━━━━━╺ 68/80(85.0%) 1.46    0:00:… 0:00:47
# 🎥 Rendering lidars for split test 🎥 ━━━━━╺ 68/80(85.0%) 1.46    0:00:… 0:00:47
# 🎥 Rendering lidars for split test 🎥 ━━━━━╺ 68/80(85.0%) 1.46    0:00:… 0:00:47
# 🎥 Rendering lidars for split test 🎥 ━━━━━╺ 68/80(85.0%) 1.46    0:00:… 0:00:47
# 🎥 Rendering lidars for split test 🎥 ━━━━━╺ 68/80(85.0%) 1.46    0:00:… 0:00:47
# 🎥 Rendering lidars for split test 🎥 ━━━━━╺ 68/80(85.0%) 1.46    0:00:… 0:00:47
# 🎥 Rendering lidars for split test 🎥 ━━━━━╺ 69/80(86.2%) 1.46    0:00:… 0:00:48
# 🎥 Rendering lidars for split test 🎥 ━━━━━╺ 69/80(86.2%) 1.46    0:00:… 0:00:48
# 🎥 Rendering lidars for split test 🎥 ━━━━━╺ 69/80(86.2%) 1.46    0:00:… 0:00:48
# 🎥 Rendering lidars for split test 🎥 ━━━━━╺ 69/80(86.2%) 1.46    0:00:… 0:00:48
# 🎥 Rendering lidars for split test 🎥 ━━━━━╺ 69/80(86.2%) 1.46    0:00:… 0:00:48
# 🎥 Rendering lidars for split test 🎥 ━━━━━╺ 69/80(86.2%) 1.46    0:00:… 0:00:48
# 🎥 Rendering lidars for split test 🎥 ━━━━━╺ 69/80(86.2%) 1.46    0:00:… 0:00:48
# 🎥 Rendering lidars for split test 🎥 ━━━━━╺ 70/80(87.5%) 1.46    0:00:… 0:00:48
# 🎥 Rendering lidars for split test 🎥 ━━━━━╺ 70/80(87.5%) 1.46    0:00:… 0:00:48
# 🎥 Rendering lidars for split test 🎥 ━━━━━╺ 70/80(87.5%) 1.46    0:00:… 0:00:48
# 🎥 Rendering lidars for split test 🎥 ━━━━━╺ 70/80(87.5%) 1.46    0:00:… 0:00:49
# 🎥 Rendering lidars for split test 🎥 ━━━━━╺ 70/80(87.5%) 1.46    0:00:… 0:00:49
# 🎥 Rendering lidars for split test 🎥 ━━━━━╺ 70/80(87.5%) 1.46    0:00:… 0:00:49
# 🎥 Rendering lidars for split test 🎥 ━━━━━╺ 70/80(87.5%) 1.46    0:00:… 0:00:49
# 🎥 Rendering lidars for split test 🎥 ━━━━━╺ 71/80(88.8%) 1.46    0:00:… 0:00:49
# 🎥 Rendering lidars for split test 🎥 ━━━━━╺ 71/80(88.8%) 1.46    0:00:… 0:00:49
# 🎥 Rendering lidars for split test 🎥 ━━━━━╺ 71/80(88.8%) 1.46    0:00:… 0:00:49
# 🎥 Rendering lidars for split test 🎥 ━━━━━╺ 71/80(88.8%) 1.46    0:00:… 0:00:49
# 🎥 Rendering lidars for split test 🎥 ━━━━━╺ 71/80(88.8%) 1.46    0:00:… 0:00:49
# 🎥 Rendering lidars for split test 🎥 ━━━━━╺ 71/80(88.8%) 1.46    0:00:… 0:00:49
# 🎥 Rendering lidars for split test 🎥 ━━━━━╺ 71/80(88.8%) 1.46    0:00:… 0:00:50
# 🎥 Rendering lidars for split test 🎥 ━━━━━╺ 72/80(90.0%) 1.46    0:00:… 0:00:50
# 🎥 Rendering lidars for split test 🎥 ━━━━━╺ 72/80(90.0%) 1.46    0:00:… 0:00:50
# 🎥 Rendering lidars for split test 🎥 ━━━━━╺ 72/80(90.0%) 1.46    0:00:… 0:00:50
# 🎥 Rendering lidars for split test 🎥 ━━━━━╺ 72/80(90.0%) 1.46    0:00:… 0:00:50
# 🎥 Rendering lidars for split test 🎥 ━━━━━╺ 72/80(90.0%) 1.46    0:00:… 0:00:50
# 🎥 Rendering lidars for split test 🎥 ━━━━━╺ 72/80(90.0%) 1.46    0:00:… 0:00:50
# 🎥 Rendering lidars for split test 🎥 ━━━━━╺ 73/80(91.2%) 1.46    0:00:… 0:00:50
# 🎥 Rendering lidars for split test 🎥 ━━━━━╺ 73/80(91.2%) 1.46    0:00:… 0:00:50
# 🎥 Rendering lidars for split test 🎥 ━━━━━╺ 73/80(91.2%) 1.46    0:00:… 0:00:50
# 🎥 Rendering lidars for split test 🎥 ━━━━━╺ 73/80(91.2%) 1.46    0:00:… 0:00:51
# 🎥 Rendering lidars for split test 🎥 ━━━━━╺ 73/80(91.2%) 1.46    0:00:… 0:00:51
# 🎥 Rendering lidars for split test 🎥 ━━━━━╺ 73/80(91.2%) 1.46    0:00:… 0:00:51
# 🎥 Rendering lidars for split test 🎥 ━━━━━╺ 73/80(91.2%) 1.46    0:00:… 0:00:51
# 🎥 Rendering lidars for split test 🎥 ━━━━━╺ 73/80(91.2%) 1.46    0:00:… 0:00:51
# 🎥 Rendering lidars for split test 🎥 ━━━━━╸ 74/80(92.5%) 1.45    0:00:… 0:00:51
# 🎥 Rendering lidars for split test 🎥 ━━━━━╸ 74/80(92.5%) 1.45    0:00:… 0:00:51
# 🎥 Rendering lidars for split test 🎥 ━━━━━╸ 74/80(92.5%) 1.45    0:00:… 0:00:51
# 🎥 Rendering lidars for split test 🎥 ━━━━━╸ 74/80(92.5%) 1.45    0:00:… 0:00:51
# 🎥 Rendering lidars for split test 🎥 ━━━━━╸ 74/80(92.5%) 1.45    0:00:… 0:00:51
# 🎥 Rendering lidars for split test 🎥 ━━━━━╸ 74/80(92.5%) 1.45    0:00:… 0:00:52
# 🎥 Rendering lidars for split test 🎥 ━━━━━╸ 74/80(92.5%) 1.45    0:00:… 0:00:52
# 🎥 Rendering lidars for split test 🎥 ━━━━━╸ 75/80(93.8%) 1.45    0:00:… 0:00:52
# 🎥 Rendering lidars for split test 🎥 ━━━━━╸ 75/80(93.8%) 1.45    0:00:… 0:00:52
# 🎥 Rendering lidars for split test 🎥 ━━━━━╸ 75/80(93.8%) 1.45    0:00:… 0:00:52
# 🎥 Rendering lidars for split test 🎥 ━━━━━╸ 75/80(93.8%) 1.45    0:00:… 0:00:52
# 🎥 Rendering lidars for split test 🎥 ━━━━━╸ 75/80(93.8%) 1.45    0:00:… 0:00:52
# 🎥 Rendering lidars for split test 🎥 ━━━━━╸ 75/80(93.8%) 1.45    0:00:… 0:00:52
# 🎥 Rendering lidars for split test 🎥 ━━━━━╸ 75/80(93.8%) 1.45    0:00:… 0:00:52
# 🎥 Rendering lidars for split test 🎥 ━━━━━╸ 76/80(95.0%) 1.45    0:00:… 0:00:52
# 🎥 Rendering lidars for split test 🎥 ━━━━━╸ 76/80(95.0%) 1.45    0:00:… 0:00:53
# 🎥 Rendering lidars for split test 🎥 ━━━━━╸ 76/80(95.0%) 1.45    0:00:… 0:00:53
# 🎥 Rendering lidars for split test 🎥 ━━━━━╸ 76/80(95.0%) 1.45    0:00:… 0:00:53
# 🎥 Rendering lidars for split test 🎥 ━━━━━╸ 76/80(95.0%) 1.45    0:00:… 0:00:53
# 🎥 Rendering lidars for split test 🎥 ━━━━━╸ 76/80(95.0%) 1.45    0:00:… 0:00:53
# 🎥 Rendering lidars for split test 🎥 ━━━━━╸ 76/80(95.0%) 1.45    0:00:… 0:00:53
# 🎥 Rendering lidars for split test 🎥 ━━━━━╸ 76/80(95.0%) 1.45    0:00:… 0:00:53
# 🎥 Rendering lidars for split test 🎥 ━━━━━╸ 77/80(96.2%) 1.45    0:00:… 0:00:53
# 🎥 Rendering lidars for split test 🎥 ━━━━━╸ 77/80(96.2%) 1.45    0:00:… 0:00:53
# 🎥 Rendering lidars for split test 🎥 ━━━━━╸ 77/80(96.2%) 1.45    0:00:… 0:00:54
# 🎥 Rendering lidars for split test 🎥 ━━━━━╸ 77/80(96.2%) 1.45    0:00:… 0:00:54
# 🎥 Rendering lidars for split test 🎥 ━━━━━╸ 77/80(96.2%) 1.45    0:00:… 0:00:54
# 🎥 Rendering lidars for split test 🎥 ━━━━━╸ 77/80(96.2%) 1.45    0:00:… 0:00:54
# 🎥 Rendering lidars for split test 🎥 ━━━━━╸ 77/80(96.2%) 1.45    0:00:… 0:00:54
# 🎥 Rendering lidars for split test 🎥 ━━━━━╸ 78/80(97.5%) 1.45    0:00:… 0:00:54
# 🎥 Rendering lidars for split test 🎥 ━━━━━╸ 78/80(97.5%) 1.45    0:00:… 0:00:54
# 🎥 Rendering lidars for split test 🎥 ━━━━━╸ 78/80(97.5%) 1.45    0:00:… 0:00:54
# 🎥 Rendering lidars for split test 🎥 ━━━━━╸ 78/80(97.5%) 1.45    0:00:… 0:00:54
# 🎥 Rendering lidars for split test 🎥 ━━━━━╸ 78/80(97.5%) 1.45    0:00:… 0:00:54
# 🎥 Rendering lidars for split test 🎥 ━━━━━╸ 78/80(97.5%) 1.45    0:00:… 0:00:55
# 🎥 Rendering lidars for split test 🎥 ━━━━━╸ 78/80(97.5%) 1.45    0:00:… 0:00:55
# 🎥 Rendering lidars for split test 🎥 ━━━━━╸ 78/80(97.5%) 1.45    0:00:… 0:00:55
# 🎥 Rendering lidars for split test 🎥 ━━━━━╸ 79/80(98.8%) 1.44    0:00:… 0:00:55
# 🎥 Rendering lidars for split test 🎥 ━━━━━╸ 79/80(98.8%) 1.44    0:00:… 0:00:55
# 🎥 Rendering lidars for split test 🎥 ━━━━━╸ 79/80(98.8%) 1.44    0:00:… 0:00:55
# 🎥 Rendering lidars for split test 🎥 ━━━━━╸ 79/80(98.8%) 1.44    0:00:… 0:00:55
# 🎥 Rendering lidars for split test 🎥 ━━━━━╸ 79/80(98.8%) 1.44    0:00:… 0:00:55
# 🎥 Rendering lidars for split test 🎥 ━━━━━╸ 79/80(98.8%) 1.44    0:00:… 0:00:55
# 🎥 Rendering lidars for split test 🎥 ━━━━━━ 80/80(100.0%) 1.44   0:00:… 0:00:55
# 🎥 Rendering lidars for split test 🎥 ━━━━━━ 80/80(100.0%) 1.44   0:00:… 0:00:55
#                                                            fps
# ╭─ 🎉 Render on split {} Complete 🎉 ─╮
# │                ╷                    │
# │   Outputs test │ shifted/011/test   │
# │                ╵                    │
# ╰─────────────────────────────────────╯

# %%
# !cp -r /workspace/datasets/self-driving/pandaset/{seq} data/pandaset/

# %%
# !cp -r shifted/{seq}/test/lidar/* data/pandaset/{seq}/lidar

# %%
# !cp -r shifted/{seq}/test/rgb/front_camera/* data/pandaset/{seq}/camera/front_camera

# %%
# !cp -r shifted/{seq}/test/rgb/left_camera/* data/pandaset/{seq}/camera/left_camera

# %%
# !cp -r shifted/{seq}/test/rgb/right_camera/* data/pandaset/{seq}/camera/right_camera

# %%
# !cp -r shifted/{seq}/test/rgb/back_camera/* data/pandaset/{seq}/camera/back_camera

# %%
# !cp -r shifted/{seq}/test/rgb/front_left_camera/* data/pandaset/{seq}/camera/front_left_camera

# %%
# !cp -r shifted/{seq}/test/rgb/front_right_camera/* data/pandaset/{seq}/camera/front_right_camera

# %% [markdown]
# ### Test

# %%
# !ls -l outputs/shifts/splatad/
# Out:
# total 12
# drwxr-xr-x 2 jovyan jovyan 4096 Oct  3 01:09 2025-10-03_010937
# drwxr-xr-x 3 jovyan jovyan 4096 Oct  3 01:16 2025-10-03_011241
# drwxr-xr-x 3 jovyan jovyan 4096 Oct  3 02:46 2025-10-03_023900

# %%
str_shift = f"{-shift[0]} {-shift[1]} {-shift[2]}"

folder = "2025-10-03_023900"
cfg = f"outputs/shifts/splatad/{folder}/config.yml"

# %%
# !python nerfstudio/scripts/render.py dataset --load-config {cfg} --output_path reverse_shifted/{seq} --shift {str_shift} --render_point_clouds True --data /workspace/datasets/self-driving/pandaset/
# Out:
# python: can't open file '/home/jovyan/users/shirokov/third-party/neurad-studio/nerfstudio/scripts/render.py': [Errno 2] No such file or directory

# %%
base_folder = f"reverse_shifted/{seq}/test"
(Path(base_folder) / "videos").mkdir(parents=True, exist_ok=True)

for selected_camera in selected_cameras:
    output_video_path = Path(base_folder) / "videos" / f"{selected_camera}.mp4"
    create_video_with_imageio(base_folder, selected_camera, output_video_path, fps, reverse=True)

# %%
base_folder = f"reverse_shifted/{seq}/test"
(Path(base_folder) / "videos").mkdir(parents=True, exist_ok=True)

output_video_path = Path(base_folder) / "videos" / f"lidar.mp4"
create_video_with_imageio(base_folder, "lidar", output_video_path, fps, reverse=True)
